# %%
import pandas as pd

# %%
url = 'https://github.com/veltman/ca-license-plates/blob/master/applications.csv?raw=true'

# %%
df = pd.read_csv(url)

# %%
df
# Out:
#           plate review_reason_code  \
# 0       AZIZ714                  2
# 1       BATBOX1                  1
# 2        BBOMBS                  2
# 3       BEACHY1                  4
# 4      BLK PWR5                  2
# ...         ...                ...
# 23458   4KTMGAL                  1
# 23459    88 CAP                  2
# 23460   BLNT 4C                  2
# 23461   VIBRATR                  1
# 23462   666KIDD                  2
#
#                                         customer_meaning  \
# 0                                              LAST NAME
# 1      BATMOBILE (BATMAN) PLUS SHAPE OF VEHICLE (SCIO...
# 2                                     NO MICRO AVAILABLE
# 3                                         LOVE THE BEACH
# 4                                     STRENGTH OF FAMILY
# ...                                                  ...
# 23458                             TO TRAILER MY KTM BIKE
# 23459                                         88 CAPITAL
# ...
